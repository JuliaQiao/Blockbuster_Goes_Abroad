# %%
import pandas as pd

# %%
kaggle_df = pd.read_csv('imdb_1972-2019.csv')

# %%
kaggle_df.sort_values(by= 'Revenue (Millions)', ascending = False)
# Out:
#       Unnamed: 0                                       Title  Year  Rating  \
# 551            2  Star Wars: Episode VII - The Force Awakens  2015     7.9
# 0              0                           Avengers: Endgame  2019     8.5
# 59             1                               Black Panther  2018     7.3
# 58             0                      Avengers: Infinity War  2018     8.5
# 4120        3571                                     Titanic  1997     7.8
# ...          ...                                         ...   ...     ...
# 507          255                                      Fallen  2016     5.6
# 511          259                     Don't Fuck in the Woods  2016     2.7
# 525          273                             Paris pieds nus  2016     6.8
# 528          276                              Hounds of Love  2016     6.7
# 543          291                                    Mindhorn  2016     6.4
#
# ...

# %%
#kaggle_df_2016 = pd.read_csv('movies 1986-2016.csv')

# %%
#checking for nulls in rating 
kaggle_df[kaggle_df['Rating'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Title, Year, Rating, Metascore, Votes, Description, Genre, Runtime (Minutes), Revenue (Millions), Actors, Director]
# Index: []

# %%
#checking for nulls in Title 
kaggle_df[kaggle_df['Title'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Title, Year, Rating, Metascore, Votes, Description, Genre, Runtime (Minutes), Revenue (Millions), Actors, Director]
# Index: []

# %%
#great! we can get rid of years beyond our time range
kaggle_df = kaggle_df[kaggle_df['Year'] > 1999]

# %%
kaggle_df['Years_Since_Release']  = 2020 - kaggle_df['Year']
# Out:
# <ipython-input-16-aef94de66be1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kaggle_df['Years_Since_Release']  = 2020 - kaggle_df['Year']

# %%
kaggle_df
# Out:
#       Unnamed: 0                      Title  Year  Rating  Metascore   Votes  \
# 0              0          Avengers: Endgame  2019     8.5       78.0  648248
# 1              1  Spider-Man: Far from Home  2019     7.6       69.0  255849
# 2              2                Toy Story 4  2019     7.9       84.0  146740
# 3              3    Jumanji: The Next Level  2019     7.0       58.0   63856
# 4              4             The Lighthouse  2019     7.8       83.0   50595
# ...          ...                        ...   ...     ...        ...     ...
# 3783        3234               Chuck & Buck  2000     6.5       76.0    5105
# 3784        3235                     Groove  2000     6.6       54.0    3917
# 3785        3236            What's Cooking?  2000     6.9       57.0    2415
# 3786        3237                Next Friday  2000     6.1       41.0   34864
# 3787        3238              Drowning Mona  2000     5.7       25.0   12812
#
# ...

# %%
kaggle_df.to_csv(r'/Users/juliaqiao/Documents/Metis/Project_2/kaggle_df.csv')
