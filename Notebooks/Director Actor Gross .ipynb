# %%
import pandas as pd

# %%
kaggle_df = pd.read_csv('imdb_1972-2019.csv')

# %%
kaggle_df.sort_values(by= 'Revenue (Millions)', ascending = False)
# Out:
#       Unnamed: 0                                       Title  Year  Rating  \
# 551            2  Star Wars: Episode VII - The Force Awakens  2015     7.9
# 0              0                           Avengers: Endgame  2019     8.5
# 59             1                               Black Panther  2018     7.3
# 58             0                      Avengers: Infinity War  2018     8.5
# 4120        3571                                     Titanic  1997     7.8
# ...          ...                                         ...   ...     ...
# 507          255                                      Fallen  2016     5.6
# 511          259                     Don't Fuck in the Woods  2016     2.7
# 525          273                             Paris pieds nus  2016     6.8
# 528          276                              Hounds of Love  2016     6.7
# 543          291                                    Mindhorn  2016     6.4
#
# ...
