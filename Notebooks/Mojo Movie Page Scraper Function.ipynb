# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import time, os
from random import randint
import pickle

# %%
#read in top movie list dataframe
movie_df = pd.read_pickle('top_movies_df.pickle')

# %%
movie_df.head()
# Out:
#                                            URL Rank  \
# 4154796  /title/tt4154796/?ref_=bo_cso_table_1    1
# 0499549  /title/tt0499549/?ref_=bo_cso_table_2    2
# 0120338  /title/tt0120338/?ref_=bo_cso_table_3    3
# 2488496  /title/tt2488496/?ref_=bo_cso_table_4    4
# 4154756  /title/tt4154756/?ref_=bo_cso_table_5    5
#
#                                               Title     World_Gross  \
# 4154796                           Avengers: Endgame  $2,797,800,564
# 0499549                                      Avatar  $2,790,439,092
# 0120338                                     Titanic  $2,195,169,869
# 2488496  Star Wars: Episode VII - The Force Awakens  $2,068,224,036
# 4154756                      Avengers: Infinity War  $2,048,359,754
#
#         Domestic_Gross Domestic_Percentage   Foreign_Gross Foreign_Percentage  \
# 4154796   $858,373,000               30.7%  $1,939,427,564              69.3%
# 0499549   $760,507,625               27.2%  $2,029,931,467              72.8%
# 0120338   $659,363,944                 30%  $1,535,805,925                70%
# 2488496   $936,662,225               45.3%  $1,131,561,811              54.7%
# 4154756   $678,815,482               33.1%  $1,369,544,272              66.9%
#
#          Year
# 4154796  2019
# 0499549  2009
# 0120338  1997
# 2488496  2015
# 4154756  2018

# %%
#turn index into list
links = movie_df.index.tolist()

# %%
links
# Out:
# ['4154796',
#  '0499549',
#  '0120338',
#  '2488496',
#  '4154756',
#  '0369610',
#  '6105098',
#  '0848228',
#  '2820852',
#  '4520988',
#  '2395427',
#  '1825683',
#  '1201607',
#  '2527336',
#  '4881806',
#  '2294629',
#  '2771200',
#  '3606756',
#  '4630562',
#  '1300854',
#  '2293640',
#  '3498820',
#  '1477834',
#  '0167260',
#  '6320628',
#  '4154664',
#  '1399103',
#  '1074638',
#  '2109248',
#  '1345836',
#  '7286456',
#  '2527338',
#  '1979376',
#  '0435761',
#  '0383574',
#  '3748528',
#  '6139732',
#  '1298650',
#  '3469046',
#  '0107290',
#  '2277860',
#  '0120915',
#  '0109830',
#  '1014759',
#  '2948356',
#  '0903624',
#  '0468569',
#  '0241527',
#  '0926084',
#  '1690953',
#  '0110357',
#  '3040964',
#  '2283362',
#  '0449088',
#  '1170358',
#  '2310332',
#  '0167261',
#  '0373889',
#  '0266543',
#  '0417741',
#  '0298148',
#  '1727824',
#  '0330373',
#  '0413300',
#  '0120737',
#  '1080016',
#  '2379713',
#  '2250912',
#  '0295297',
#  '1667889',
#  '2709768',
#  '2975590',
#  '7131870',
#  '0121766',
#  '1951264',
#  '3896198',
#  '2096673',
#  '1270797',
#  '3501632',
#  '1375666',
#  '1055369',
#  '1673434',
#  '0145487',
#  '0451279',
#  '0116629',
#  '3183660',
#  '0413267',
#  '2380307',
#  '7975244',
#  '0304141',
#  '1790809',
#  '0083866',
#  '1190080',
#  '4912910',
#  '0367882',
#  '0316654',
#  '1905041',
#  '5463162',
#  '1431045',
#  '0076759',
#  '2015381',
#  '0382625',
#  '6806448',
#  '1587310',
#  '0948470',
#  '1951265',
#  '0892791',
#  '1277953',
#  '1386697',
#  '0110478',
#  '1667353',
#  '0120744',
#  '0101540',
#  '0338094',
#  '0114924',
#  '0112579',
#  '0409182',
#  '0116313',
#  '0331632',
#  '0102059',
#  '0257044',
#  '0266697',
#  '0277296',
#  '0256415',
#  '5657846',
#  '0453467',
#  '2119532',
#  '6294822',
#  '0112792',
#  '1645170',
#  '0311429',
#  '3410834',
#  '0287978',
#  '6324278',
#  '0101587',
#  '1001508',
#  '1059786',
#  '0343135',
#  '0424095',
#  '0362120',
#  '0118928',
#  '0388795',
#  '0105112',
#  '0119137',
#  '1469304',
#  '0150377',
#  '1568911',
#  '1536044',
#  '0251127',
#  '0370263',
#  '0299977',
#  '0405422',
#  '1327773',
#  '0171363',
#  '1033575',
#  '0429493',
#  '0084805',
#  '0107206',
#  '0122933',
#  '1959563',
#  '1276104',
#  '2076298',
#  '0240462',
#  '0317740',
#  '0825232',
#  '0102945',
#  '0409847',
#  '7959026',
#  '0119190',
#  '0413099',
#  '2024432',
#  '5523010',
#  '0208003',
#  '1637688',
#  '0211915',
#  '6044910',
#  '1229340',
#  '3076658',
#  '1025100',
#  '3631112',
#  '0117571',
#  '0159365',
#  '0265086',
#  '2278388',
#  '0304669',
#  '1060277',
#  '0120082',
#  '1078940',
#  '0120587',
#  '0450259',
#  '1116184',
#  '0477348',
#  '5814534',
#  '4425200',
#  '0094889',
#  '0280590',
#  '0118884',
#  '0829482',
#  '1386588',
#  '0111255',
#  '2302755',
#  '0335438',
#  '0358135',
#  '0243585',
#  '1222817',
#  '2096672',
#  '1219827',
#  '0119698',
#  '0814314',
#  '0396555',
#  '0120917',
#  '0114746',
#  '0364725',
#  '0411477',
#  '5726086',
#  '1502712',
#  '0477080',
#  '0094137',
#  '1915581',
#  ...]

# %%
def mojo_movie_dict(url_id):
    '''
    From BoxOfficeMojo link stub, request movie html, parse with BeautifulSoup, and
    collect 
        - title 
        - domestic opening gross
        - MPAA rating 
        - foreign market count
        - genres
        - distributor
        - director 
        - actor, first billing
        - actor, second billing
        - IMDB link
    Return information as a dictionary.
    '''
    
    base_url = 'https://www.boxofficemojo.com/title/tt'
    
    url = base_url + url_id
        
    #Request HTML and parse
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")

    
    headers = ['id', 'mojo_title', 'domestic_opening_gross',
                'rating', 'foreign_market_count', 'genres', 'distributor',
                'director', 'actor_1', 'actor_2', 'IMDB_link']
    
    #Get title
    title_string = soup.find(class_= 'a-size-extra-large').text
    mojo_title = title_string.split('(')[0].strip()


    #Get distribution company
    distributor= soup.find(class_='a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile').find_all('span')[1].contents[0] 

    #Get domestic opening
    try:
        domestic_opening = soup.find(text='Domestic Opening').findNext().find(class_= 'money').text
    except:
        domestic_opening = np.nan

    #Get rating
    try:
        rating = soup.find(text='MPAA').findNext().text

    except:
        rating = np.nan 

    #find foreign markets, depending on format
    try: 
        if soup.find(text = 'Markets'):
            foreign_markets = soup.find('table', class_= 'a-bordered a-horizontal-stripes a-size-base-plus').find_all(class_='a-link-normal')[1].text[0:2]

        else:
            market_links = soup.find(class_='a-section mojo-h-scroll').find_all(class_= 'a-link-normal')
            foreign_markets = len(market_links)-1
    except:
        foreign_markets = np.nan

    #find genres
    try:
        genres = soup.find(text='Genres').findNext().text
    except:
        genres = np.nan

    #find IMDB movie page link and strip off reference parts of URL (everything after ?)
    try:
        link_string = soup.find(class_='a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile').find_all('a', class_='a-link-normal')[-1]['href']
        link_string = link_string.split('?')[0].strip()
    except:
        link_string = np.nan

    #create url to scrape credits page
    credits_url = url+'/credits'

    #Request HTML and parse
    response = requests.get(credits_url)
    page = response.text
    credits_soup = BeautifulSoup(page,"lxml")

    #find director(first)

    director = credits_soup.find(id = 'principalCrew').find_all('tr')[1].text.split("\n",1)[0]

    #find principal actor
    actor_1 = credits_soup.find(id = 'principalCast').find_all('tr')[1].text.split("\n",1)[0]

    #find second actor
    actor_2 = actor_2 = credits_soup.find(id = 'principalCast').find_all('tr')[2].text.split("\n",1)[0]

    #Create movie dictionary and return
    mojo_dict = dict(zip(headers, [url_id, 
                                mojo_title,
                                domestic_opening,
                                rating, 
                                foreign_markets,
                                genres,
                                distributor,
                                director,
                                actor_1,
                                actor_2,
                                link_string]))


    return mojo_dict

# %%
#break url list into sections, due to errors with website when scraping as a whole.
first_100 = links[0:100]
len(first_100)
# Out:
# 100

# %%
second_100 = links[100:200]
len(second_100)

# %%
third_100 = links[200:300]
len(third_100)
# Out:
# 100

# %%
fourth_100 = links[300:400]

# %%
fifth_100 = links[400:500]

# %%
sixth_100 = links[500:600]

# %%
#cleaning out a page that can't be scraped and isn't a domestic production
#would've had to clean it out later anyway
sixth_100.remove('4276752')

# %%
len(sixth_100)
# Out:
# 99

# %%
seventh_100 = links[600:700]
len(seventh_100)
# Out:
# 100

# %%
eigth_100 = links[700:800]

# %%
ninth_100 = links[800:900]
len(ninth_100)
# Out:
# 100

# %%
tenth_100 = links[900:1000]
len(tenth_100)
# Out:
# 100

# %%
eleventh_100 = links[1000:1100]
len(eleventh_100)
# Out:
# 100

# %%
twelfth_100 = links[1100:1200]
len(twelfth_100)
# Out:
# 100

# %%
#cleaning out a page that can't be scraped.

twelfth_100.remove('0112715')

# %%
len(twelfth_100)
# Out:
# 99

# %%
#creating a list to store dictionary outputs from scraper function
mojo_dict_list = []

# %%
#feeding partial link lists into function which takes in partial list, scrapes each url
#returns dictionary of values for each movie url page and appends it into existing list.
for link in sixth_100:
    mojo_dict_list.append(mojo_movie_dict(link))
    
    #random sleep counter 1-4 seconds to avoid being blocked while scraping
    time.sleep(randint(4,6))

# %%
mojo_dict_list
# Out:
# [{'id': '0433035',
#   'mojo_title': 'Real Steel',
#   'domestic_opening_gross': '$27,319,677',
#   'rating': 'PG-13',
#   'foreign_market_count': 51,
#   'genres': 'Action\n    \n        Drama\n    \n        Sci-Fi\n    \n        Sport',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'director': 'Shawn Levy',
#   'actor_1': 'Hugh Jackman',
#   'actor_2': 'Evangeline Lilly',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0433035'},
#  {'id': '0451079',
#   'mojo_title': 'Horton Hears a Who!',
#   'domestic_opening_gross': '$45,012,998',
#   'rating': nan,
#   'foreign_market_count': 74,
#   'genres': 'Adventure\n    \n        Animation\n    \n        Comedy\n    \n        Family\n    \n        Fantasy',
#   'distributor': 'Twentieth Century Fox',
#   'director': 'Jimmy Hayward',
#   'actor_1': 'Jim Carrey',
#   'actor_2': 'Steve Carell',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0451079'},
#  {'id': '5164214',
#   'mojo_title': "Ocean's 8",
#   'domestic_opening_gross': '$41,607,378',
#   'rating': 'PG-13',
#   'foreign_market_count': 40,
#   'genres': 'Action\n    \n        Comedy\n    \n        Crime\n    \n        Thriller',
#   'distributor': 'Warner Bros.',
#   'director': 'Gary Ross',
#   'actor_1': 'Sandra Bullock',
#   'actor_2': 'Cate Blanchett',
#   'IMDB_link': 'https://pro.imdb.com/title/tt5164214'},
#  {'id': '2908446',
#   'mojo_title': 'The Divergent Series: Insurgent',
#   'domestic_opening_gross': '$52,263,680',
#   'rating': 'PG-13',
#   'foreign_market_count': 67,
#   'genres': 'Action\n    \n        Adventure\n    \n        Sci-Fi\n    \n        Thriller',
#   'distributor': 'Lionsgate',
#   'director': 'Robert Schwentke',
#   'actor_1': 'Shailene Woodley',
#   'actor_2': 'Ansel Elgort',
#   'IMDB_link': 'https://pro.imdb.com/title/tt2908446'},
#  {'id': '0097778',
#   'mojo_title': "Look Who's Talking",
#   'domestic_opening_gross': '$12,107,784',
#   'rating': nan,
#   'foreign_market_count': 0,
#   'genres': 'Comedy',
#   'distributor': 'TriStar Pictures',
#   'director': 'Amy Heckerling',
#   'actor_1': 'John Travolta',
#   'actor_2': 'Kirstie Alley',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0097778'},
#  {'id': '0295178',
#   'mojo_title': 'Austin Powers in Goldmember',
#   'domestic_opening_gross': '$73,071,188',
#   'rating': 'PG-13',
#   'foreign_market_count': 52,
#   'genres': 'Action\n    \n        Adventure\n    \n        Comedy\n    \n        Crime',
#   'distributor': 'New Line Cinema',
#   'director': 'Jay Roach',
#   'actor_1': 'Mike Myers',
#   'actor_2': 'Beyoncé',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0295178'},
#  {'id': '1935859',
#   'mojo_title': "Miss Peregrine's Home for Peculiar Children",
#   'domestic_opening_gross': '$28,871,140',
#   'rating': 'PG-13',
#   'foreign_market_count': 47,
#   'genres': 'Adventure\n    \n        Drama\n    \n        Family\n    \n        Fantasy\n    \n        Thriller',
#   'distributor': 'Twentieth Century Fox',
#   'director': 'Tim Burton',
#   'actor_1': 'Eva Green',
#   'actor_2': 'Asa Butterfield',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1935859'},
#  {'id': '0087332',
#   'mojo_title': 'Ghostbusters',
#   'domestic_opening_gross': '$13,578,151',
#   'rating': nan,
#   'foreign_market_count': 'Do',
#   'genres': 'Action\n    \n        Comedy\n    \n        Fantasy',
#   'distributor': 'Columbia Pictures',
#   'director': 'Ivan Reitman',
#   'actor_1': 'Bill Murray',
#   'actor_2': 'Dan Aykroyd',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0087332'},
#  {'id': '0120903',
#   'mojo_title': 'X-Men',
#   'domestic_opening_gross': '$54,471,475',
#   'rating': 'PG-13',
#   'foreign_market_count': 61,
#   'genres': 'Action\n    \n        Adventure\n    \n        Sci-Fi',
#   'distributor': 'Twentieth Century Fox',
#   'director': 'Bryan Singer',
#   'actor_1': 'Patrick Stewart',
#   'actor_2': 'Hugh Jackman',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0120903'},
#  {'id': '3411444',
#   'mojo_title': 'Ferdinand',
#   'domestic_opening_gross': '$13,401,586',
#   'rating': 'PG',
#   'foreign_market_count': 69,
#   'genres': 'Adventure\n    \n        Animation\n    \n        Comedy\n    \n        Family\n    \n        Fantasy',
#   'distributor': 'Twentieth Century Fox',
#   'director': 'Carlos Saldanha',
#   'actor_1': 'John Cena',
#   'actor_2': 'Kate McKinnon',
#   'IMDB_link': 'https://pro.imdb.com/title/tt3411444'},
#  {'id': '1130884',
#   'mojo_title': 'Shutter Island',
#   'domestic_opening_gross': '$41,062,440',
#   'rating': 'R',
#   'foreign_market_count': 59,
#   'genres': 'Mystery\n    \n        Thriller',
#   'distributor': 'Paramount Pictures',
#   'director': 'Martin Scorsese',
#   'actor_1': 'Leonardo DiCaprio',
#   'actor_2': 'Emily Mortimer',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1130884'},
#  {'id': '0118998',
#   'mojo_title': 'Doctor Dolittle',
#   'domestic_opening_gross': '$29,014,324',
#   'rating': 'PG-13',
#   'foreign_market_count': 0,
#   'genres': 'Comedy\n    \n        Family\n    \n        Fantasy',
#   'distributor': 'Twentieth Century Fox',
#   'director': 'Betty Thomas',
#   'actor_1': 'Eddie Murphy',
#   'actor_2': 'Peter Boyle',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0118998'},
#  {'id': '0389790',
#   'mojo_title': 'Bee Movie',
#   'domestic_opening_gross': '$38,021,044',
#   'rating': 'PG',
#   'foreign_market_count': 66,
#   'genres': 'Adventure\n    \n        Animation\n    \n        Comedy\n    \n        Family',
#   'distributor': 'DreamWorks',
#   'director': 'Simon J. Smith',
#   'actor_1': 'Jerry Seinfeld',
#   'actor_2': 'Renée Zellweger',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0389790'},
#  {'id': '0944835',
#   'mojo_title': 'Salt',
#   'domestic_opening_gross': '$36,011,243',
#   'rating': 'PG-13',
#   'foreign_market_count': 62,
#   'genres': 'Action\n    \n        Thriller',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'director': 'Phillip Noyce',
#   'actor_1': 'Angelina Jolie',
#   'actor_2': 'Liev Schreiber',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0944835'},
#  {'id': '0436339',
#   'mojo_title': 'G-Force',
#   'domestic_opening_gross': '$31,706,934',
#   'rating': 'PG',
#   'foreign_market_count': 60,
#   'genres': 'Action\n    \n        Adventure\n    \n        Animation\n    \n        Comedy\n    \n        Family\n    \n        Fantasy\n    \n        Sci-Fi',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'director': 'Hoyt Yeatman',
#   'actor_1': 'Will Arnett',
#   'actor_2': 'Penélope Cruz',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0436339'},
#  {'id': '0407887',
#   'mojo_title': 'The Departed',
#   'domestic_opening_gross': '$26,887,467',
#   'rating': 'R',
#   'foreign_market_count': 46,
#   'genres': 'Crime\n    \n        Drama\n    \n        Thriller',
#   'distributor': 'Warner Bros.',
#   'director': 'Martin Scorsese',
#   'actor_1': 'Leonardo DiCaprio',
#   'actor_2': 'Matt Damon',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0407887'},
#  {'id': '0161081',
#   'mojo_title': 'What Lies Beneath',
#   'domestic_opening_gross': '$29,702,959',
#   'rating': 'PG-13',
#   'foreign_market_count': 30,
#   'genres': 'Drama\n    \n        Fantasy\n    \n        Horror\n    \n        Mystery\n    \n        Thriller',
#   'distributor': 'DreamWorks Distribution',
#   'director': 'Robert Zemeckis',
#   'actor_1': 'Harrison Ford',
#   'actor_2': 'Michelle Pfeiffer',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0161081'},
#  {'id': '2557478',
#   'mojo_title': 'Pacific Rim: Uprising',
#   'domestic_opening_gross': '$28,116,535',
#   'rating': 'PG-13',
#   'foreign_market_count': 65,
#   'genres': 'Action\n    \n        Adventure\n    \n        Sci-Fi',
#   'distributor': 'Universal Pictures',
#   'director': 'Steven S. DeKnight',
#   'actor_1': 'John Boyega',
#   'actor_2': 'Scott Eastwood',
#   'IMDB_link': 'https://pro.imdb.com/title/tt2557478'},
#  {'id': '0372183',
#   'mojo_title': 'The Bourne Supremacy',
#   'domestic_opening_gross': '$52,521,865',
#   'rating': 'PG-13',
#   'foreign_market_count': '61',
#   'genres': 'Action\n    \n        Mystery\n    \n        Thriller',
#   'distributor': 'Universal Pictures',
#   'director': 'Paul Greengrass',
#   'actor_1': 'Matt Damon',
#   'actor_2': 'Franka Potente',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0372183'},
#  {'id': '1261945',
#   'mojo_title': 'Sex and the City 2',
#   'domestic_opening_gross': '$31,001,870',
#   'rating': 'R',
#   'foreign_market_count': 57,
#   'genres': 'Comedy\n    \n        Drama\n    \n        Romance',
#   'distributor': 'Warner Bros.',
#   'director': 'Michael Patrick King',
#   'actor_1': 'Sarah Jessica Parker',
#   'actor_2': 'Kim Cattrall',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1261945'},
#  {'id': '0138097',
#   'mojo_title': 'Shakespeare in Love',
#   'domestic_opening_gross': '$224,012',
#   'rating': 'R',
#   'foreign_market_count': 0,
#   'genres': 'Comedy\n    \n        Drama\n    \n        History\n    \n        Romance',
#   'distributor': 'Miramax',
#   'director': 'John Madden',
#   'actor_1': 'Gwyneth Paltrow',
#   'actor_2': 'Joseph Fiennes',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0138097'},
#  {'id': '1840309',
#   'mojo_title': 'Divergent',
#   'domestic_opening_gross': '$54,607,747',
#   'rating': 'PG-13',
#   'foreign_market_count': 53,
#   'genres': 'Action\n    \n        Adventure\n    \n        Mystery\n    \n        Sci-Fi',
#   'distributor': 'Lionsgate',
#   'director': 'Neil Burger',
#   'actor_1': 'Shailene Woodley',
#   'actor_2': 'Theo James',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1840309'},
#  {'id': '0094898',
#   'mojo_title': 'Coming to America',
#   'domestic_opening_gross': '$21,404,420',
#   'rating': nan,
#   'foreign_market_count': 0,
#   'genres': 'Comedy\n    \n        Romance',
#   'distributor': 'Paramount Pictures',
#   'director': 'John Landis',
#   'actor_1': 'Eddie Murphy',
#   'actor_2': 'Paul Bates',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0094898'},
#  {'id': '0396269',
#   'mojo_title': 'Wedding Crashers',
#   'domestic_opening_gross': '$32,200,000',
#   'rating': 'R',
#   'foreign_market_count': 54,
#   'genres': 'Comedy\n    \n        Romance',
#   'distributor': 'New Line Cinema',
#   'director': 'David Dobkin',
#   'actor_1': 'Owen Wilson',
#   'actor_2': 'Vince Vaughn',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0396269'},
#  {'id': '1478338',
#   'mojo_title': 'Bridesmaids',
#   'domestic_opening_gross': '$26,247,410',
#   'rating': 'R',
#   'foreign_market_count': 53,
#   'genres': 'Comedy\n    \n        Romance',
#   'distributor': 'Universal Pictures',
#   'director': 'Paul Feig',
#   'actor_1': 'Kristen Wiig',
#   'actor_2': 'Maya Rudolph',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1478338'},
#  {'id': '4500922',
#   'mojo_title': 'Maze Runner: The Death Cure',
#   'domestic_opening_gross': '$24,167,011',
#   'rating': 'PG-13',
#   'foreign_market_count': 70,
#   'genres': 'Action\n    \n        Adventure\n    \n        Sci-Fi\n    \n        Thriller',
#   'distributor': 'Twentieth Century Fox',
#   'director': 'Wes Ball',
#   'actor_1': "Dylan O'Brien",
#   'actor_2': 'Ki Hong Lee',
#   'IMDB_link': 'https://pro.imdb.com/title/tt4500922'},
#  {'id': '0112642',
#   'mojo_title': 'Casper',
#   'domestic_opening_gross': '$16,840,385',
#   'rating': 'PG',
#   'foreign_market_count': 0,
#   'genres': 'Comedy\n    \n        Family\n    \n        Fantasy',
#   'distributor': 'Universal Pictures',
#   'director': 'Brad Silberling',
#   'actor_1': 'Bill Pullman',
#   'actor_2': 'Christina Ricci',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0112642'},
#  {'id': '0252866',
#   'mojo_title': 'American Pie 2',
#   'domestic_opening_gross': '$45,117,985',
#   'rating': 'R',
#   'foreign_market_count': 17,
#   'genres': 'Comedy',
#   'distributor': 'Universal Pictures',
#   'director': 'J.B. Rogers',
#   'actor_1': 'Jason Biggs',
#   'actor_2': 'Seann William Scott',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0252866'},
#  {'id': '2848292',
#   'mojo_title': 'Pitch Perfect 2',
#   'domestic_opening_gross': '$69,216,890',
#   'rating': 'PG-13',
#   'foreign_market_count': 58,
#   'genres': 'Comedy\n    \n        Music',
#   'distributor': 'Universal Pictures',
#   'director': 'Elizabeth Banks',
#   'actor_1': 'Anna Kendrick',
#   'actor_2': 'Rebel Wilson',
#   'IMDB_link': 'https://pro.imdb.com/title/tt2848292'},
#  {'id': '0120689',
#   'mojo_title': 'The Green Mile',
#   'domestic_opening_gross': '$18,017,152',
#   'rating': 'R',
#   'foreign_market_count': 1,
#   'genres': 'Crime\n    \n        Drama\n    \n        Fantasy\n    \n        Mystery',
#   'distributor': 'Warner Bros.',
#   'director': 'Frank Darabont',
#   'actor_1': 'Tom Hanks',
#   'actor_2': 'Michael Clarke Duncan',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0120689'},
#  {'id': '1483013',
#   'mojo_title': 'Oblivion',
#   'domestic_opening_gross': '$37,054,485',
#   'rating': 'PG-13',
#   'foreign_market_count': 55,
#   'genres': 'Action\n    \n        Adventure\n    \n        Sci-Fi',
#   'distributor': 'Universal Pictures',
#   'director': 'Joseph Kosinski',
#   'actor_1': 'Tom Cruise',
#   'actor_2': 'Morgan Freeman',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1483013'},
#  {'id': '1535108',
#   'mojo_title': 'Elysium',
#   'domestic_opening_gross': '$29,807,393',
#   'rating': 'R',
#   'foreign_market_count': 56,
#   'genres': 'Action\n    \n        Drama\n    \n        Sci-Fi',
#   'distributor': 'TriStar Pictures',
#   'director': 'Neill Blomkamp',
#   'actor_1': 'Matt Damon',
#   'actor_2': 'Jodie Foster',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1535108'},
#  {'id': '0122151',
#   'mojo_title': 'Lethal Weapon 4',
#   'domestic_opening_gross': '$34,048,124',
#   'rating': 'R',
#   'foreign_market_count': 0,
#   'genres': 'Action\n    \n        Crime\n    \n        Thriller',
#   'distributor': 'Warner Bros.',
#   'director': 'Richard Donner',
#   'actor_1': 'Mel Gibson',
#   'actor_2': 'Danny Glover',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0122151'},
#  {'id': '0401729',
#   'mojo_title': 'John Carter',
#   'domestic_opening_gross': '$30,180,188',
#   'rating': 'PG-13',
#   'foreign_market_count': 52,
#   'genres': 'Action\n    \n        Adventure\n    \n        Sci-Fi',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'director': 'Andrew Stanton',
#   'actor_1': 'Taylor Kitsch',
#   'actor_2': 'Lynn Collins',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0401729'},
#  {'id': '1860353',
#   'mojo_title': 'Turbo',
#   'domestic_opening_gross': '$21,312,625',
#   'rating': 'PG',
#   'foreign_market_count': 55,
#   'genres': 'Adventure\n    \n        Animation\n    \n        Comedy\n    \n        Family\n    \n        Sci-Fi\n    \n        Sport',
#   'distributor': 'Twentieth Century Fox',
#   'director': 'David Soren',
#   'actor_1': 'Ryan Reynolds',
#   'actor_2': 'Paul Giamatti',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1860353'},
#  {'id': '1109624',
#   'mojo_title': 'Paddington',
#   'domestic_opening_gross': '$18,966,676',
#   'rating': 'PG',
#   'foreign_market_count': '56',
#   'genres': 'Adventure\n    \n        Comedy\n    \n        Family\n    \n        Fantasy',
#   'distributor': 'Dimension Films',
#   'director': 'Paul King',
#   'actor_1': 'Hugh Bonneville',
#   'actor_2': 'Sally Hawkins',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1109624'},
#  {'id': '0243155',
#   'mojo_title': "Bridget Jones's Diary",
#   'domestic_opening_gross': '$10,733,933',
#   'rating': 'R',
#   'foreign_market_count': 15,
#   'genres': 'Comedy\n    \n        Drama\n    \n        Romance',
#   'distributor': 'Miramax',
#   'director': 'Sharon Maguire',
#   'actor_1': 'Renée Zellweger',
#   'actor_2': 'Colin Firth',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0243155'},
#  {'id': '1243957',
#   'mojo_title': 'The Tourist',
#   'domestic_opening_gross': '$16,472,458',
#   'rating': 'PG-13',
#   'foreign_market_count': 69,
#   'genres': 'Action\n    \n        Crime\n    \n        Romance\n    \n        Thriller',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'director': 'Florian Henckel von Donnersmarck',
#   'actor_1': 'Johnny Depp',
#   'actor_2': 'Angelina Jolie',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1243957'},
#  {'id': '4972582',
#   'mojo_title': 'Split',
#   'domestic_opening_gross': '$40,010,975',
#   'rating': 'PG-13',
#   'foreign_market_count': 64,
#   'genres': 'Horror\n    \n        Thriller',
#   'distributor': 'Universal Pictures',
#   'director': 'M. Night Shyamalan',
#   'actor_1': 'James McAvoy',
#   'actor_2': 'Anya Taylor-Joy',
#   'IMDB_link': 'https://pro.imdb.com/title/tt4972582'},
#  {'id': '0175142',
#   'mojo_title': 'Scary Movie',
#   'domestic_opening_gross': '$42,346,669',
#   'rating': 'R',
#   'foreign_market_count': 1,
#   'genres': 'Comedy',
#   'distributor': 'Miramax',
#   'director': 'Keenen Ivory Wayans',
#   'actor_1': 'Anna Faris',
#   'actor_2': 'Jon Abrahams',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0175142'},
#  {'id': '0295701',
#   'mojo_title': 'xXx',
#   'domestic_opening_gross': '$44,506,103',
#   'rating': 'PG-13',
#   'foreign_market_count': 28,
#   'genres': 'Action\n    \n        Adventure\n    \n        Thriller',
#   'distributor': 'Revolution Studios',
#   'director': 'Rob Cohen',
#   'actor_1': 'Vin Diesel',
#   'actor_2': 'Asia Argento',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0295701'},
#  {'id': '1194173',
#   'mojo_title': 'The Bourne Legacy',
#   'domestic_opening_gross': '$38,142,825',
#   'rating': 'PG-13',
#   'foreign_market_count': 55,
#   'genres': 'Action\n    \n        Adventure\n    \n        Thriller',
#   'distributor': 'Universal Pictures',
#   'director': 'Tony Gilroy',
#   'actor_1': 'Jeremy Renner',
#   'actor_2': 'Rachel Weisz',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1194173'},
#  {'id': '0864835',
#   'mojo_title': 'Mr. Peabody & Sherman',
#   'domestic_opening_gross': '$32,207,057',
#   'rating': 'PG',
#   'foreign_market_count': 55,
#   'genres': 'Adventure\n    \n        Animation\n    \n        Comedy\n    \n        Family\n    \n        Sci-Fi',
#   'distributor': 'Twentieth Century Fox',
#   'director': 'Rob Minkoff',
#   'actor_1': 'Ty Burrell',
#   'actor_2': 'Max Charles',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0864835'},
#  {'id': '0267913',
#   'mojo_title': 'Scooby-Doo',
#   'domestic_opening_gross': '$54,155,312',
#   'rating': 'PG',
#   'foreign_market_count': 27,
#   'genres': 'Adventure\n    \n        Comedy\n    \n        Family\n    \n        Fantasy\n    \n        Mystery',
#   'distributor': 'Warner Bros.',
#   'director': 'Raja Gosnell',
#   'actor_1': 'Matthew Lillard',
#   'actor_2': 'Freddie Prinze Jr.',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0267913'},
#  {'id': '0443272',
#   'mojo_title': 'Lincoln',
#   'domestic_opening_gross': '$944,308',
#   'rating': 'PG-13',
#   'foreign_market_count': 51,
#   'genres': 'Biography\n    \n        Drama\n    \n        History\n    \n        War',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'director': 'Steven Spielberg',
#   'actor_1': 'Daniel Day-Lewis',
#   'actor_2': 'Sally Field',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0443272'},
#  {'id': '0146316',
#   'mojo_title': 'Lara Croft: Tomb Raider',
#   'domestic_opening_gross': '$47,735,743',
#   'rating': 'PG-13',
#   'foreign_market_count': 53,
#   'genres': 'Action\n    \n        Adventure\n    \n        Fantasy\n    \n        Thriller',
#   'distributor': 'Paramount Pictures',
#   'director': 'Simon West',
#   'actor_1': 'Angelina Jolie',
#   'actor_2': 'Jon Voight',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0146316'},
#  {'id': '1365519',
#   'mojo_title': 'Tomb Raider',
#   'domestic_opening_gross': '$23,633,317',
#   'rating': 'PG-13',
#   'foreign_market_count': 42,
#   'genres': 'Action\n    \n        Adventure\n    \n        Fantasy\n    \n        Thriller',
#   'distributor': 'Warner Bros.',
#   'director': 'Roar Uthaug',
#   'actor_1': 'Alicia Vikander',
#   'actor_2': 'Dominic West',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1365519'},
#  {'id': '1320253',
#   'mojo_title': 'The Expendables',
#   'domestic_opening_gross': '$34,825,135',
#   'rating': 'R',
#   'foreign_market_count': 53,
#   'genres': 'Action\n    \n        Adventure\n    \n        Thriller',
#   'distributor': 'Lionsgate',
#   'director': 'Sylvester Stallone',
#   'actor_1': 'Sylvester Stallone',
#   'actor_2': 'Jason Statham',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1320253'},
#  {'id': '1985966',
#   'mojo_title': 'Cloudy With a Chance of Meatballs 2',
#   'domestic_opening_gross': '$34,017,930',
#   'rating': 'PG',
#   'foreign_market_count': 54,
#   'genres': 'Adventure\n    \n        Animation\n    \n        Comedy\n    \n        Family\n    \n        Fantasy\n    \n        Sci-Fi',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'director': 'Cody Cameron',
#   'actor_1': 'Bill Hader',
#   'actor_2': 'Anna Faris',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1985966'},
#  {'id': '0097757',
#   'mojo_title': 'The Little Mermaid',
#   'domestic_opening_gross': '$6,031,914',
#   'rating': nan,
#   'foreign_market_count': 'AP',
#   'genres': 'Animation\n    \n        Family\n    \n        Fantasy\n    \n        Musical\n    \n        Romance',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'director': 'Ron Clements',
#   'actor_1': 'Jodi Benson',
#   'actor_2': 'Samuel E. Wright',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0097757'},
#  {'id': '0117218',
#   'mojo_title': 'The Nutty Professor',
#   'domestic_opening_gross': '$25,411,725',
#   'rating': 'PG-13',
#   'foreign_market_count': 0,
#   'genres': 'Comedy\n    \n        Romance\n    \n        Sci-Fi',
#   'distributor': 'Universal Pictures',
#   'director': 'Tom Shadyac',
#   'actor_1': 'Eddie Murphy',
#   'actor_2': 'Jada Pinkett Smith',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0117218'},
#  {'id': '0116695',
#   'mojo_title': 'Jerry Maguire',
#   'domestic_opening_gross': '$17,084,296',
#   'rating': 'R',
#   'foreign_market_count': 0,
#   'genres': 'Comedy\n    \n        Drama\n    \n        Romance\n    \n        Sport',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'director': 'Cameron Crowe',
#   'actor_1': 'Tom Cruise',
#   'actor_2': 'Cuba Gooding Jr.',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0116695'},
#  {'id': '0172156',
#   'mojo_title': 'Bad Boys II',
#   'domestic_opening_gross': '$46,522,560',
#   'rating': 'R',
#   'foreign_market_count': 26,
#   'genres': 'Action\n    \n        Comedy\n    \n        Crime\n    \n        Thriller',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'director': 'Michael Bay',
#   'actor_1': 'Will Smith',
#   'actor_2': 'Martin Lawrence',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0172156'},
#  {'id': '0275847',
#   'mojo_title': 'Lilo & Stitch',
#   'domestic_opening_gross': '$35,260,212',
#   'rating': 'PG',
#   'foreign_market_count': 26,
#   'genres': 'Adventure\n    \n        Animation\n    \n        Comedy\n    \n        Drama\n    \n        Family\n    \n        Fantasy\n    \n        Sci-Fi',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'director': 'Dean DeBlois',
#   'actor_1': 'Daveigh Chase',
#   'actor_2': 'Chris Sanders',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0275847'},
#  {'id': '0102926',
#   'mojo_title': 'The Silence of the Lambs',
#   'domestic_opening_gross': '$13,766,814',
#   'rating': nan,
#   'foreign_market_count': 'Do',
#   'genres': 'Crime\n    \n        Drama\n    \n        Thriller',
#   'distributor': 'Orion Pictures',
#   'director': 'Jonathan Demme',
#   'actor_1': 'Jodie Foster',
#   'actor_2': 'Anthony Hopkins',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0102926'},
#  {'id': '1375670',
#   'mojo_title': 'Grown Ups',
#   'domestic_opening_gross': '$40,506,562',
#   'rating': 'PG-13',
#   'foreign_market_count': '61',
#   'genres': 'Comedy',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'director': 'Dennis Dugan',
#   'actor_1': 'Adam Sandler',
#   'actor_2': 'Salma Hayek',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1375670'},
#  {'id': '2004420',
#   'mojo_title': 'Neighbors',
#   'domestic_opening_gross': '$49,033,915',
#   'rating': 'R',
#   'foreign_market_count': 48,
#   'genres': 'Comedy',
#   'distributor': 'Universal Pictures',
#   'director': 'Nicholas Stoller',
#   'actor_1': 'Seth Rogen',
#   'actor_2': 'Rose Byrne',
#   'IMDB_link': 'https://pro.imdb.com/title/tt2004420'},
#  {'id': '0106918',
#   'mojo_title': 'The Firm',
#   'domestic_opening_gross': '$25,400,000',
#   'rating': 'R',
#   'foreign_market_count': 0,
#   'genres': 'Drama\n    \n        Mystery\n    \n        Thriller',
#   'distributor': 'Paramount Pictures',
#   'director': 'Sydney Pollack',
#   'actor_1': 'Tom Cruise',
#   'actor_2': 'Jeanne Tripplehorn',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0106918'},
#  {'id': '1723121',
#   'mojo_title': "We're the Millers",
#   'domestic_opening_gross': '$26,419,396',
#   'rating': 'R',
#   'foreign_market_count': 50,
#   'genres': 'Comedy\n    \n        Crime',
#   'distributor': 'Warner Bros.',
#   'director': 'Rawson Marshall Thurber',
#   'actor_1': 'Jason Sudeikis',
#   'actor_2': 'Jennifer Aniston',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1723121'},
#  {'id': '1205489',
#   'mojo_title': 'Gran Torino',
#   'domestic_opening_gross': '$271,720',
#   'rating': 'R',
#   'foreign_market_count': 58,
#   'genres': 'Drama',
#   'distributor': 'Warner Bros.',
#   'director': 'Clint Eastwood',
#   'actor_1': 'Clint Eastwood',
#   'actor_2': 'Bee Vang',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1205489'},
#  {'id': '0443649',
#   'mojo_title': '10,000 BC',
#   'domestic_opening_gross': '$35,867,488',
#   'rating': 'PG-13',
#   'foreign_market_count': 64,
#   'genres': 'Action\n    \n        Adventure\n    \n        Drama\n    \n        Fantasy\n    \n        History',
#   'distributor': 'Warner Bros.',
#   'director': 'Roland Emmerich',
#   'actor_1': 'Camilla Belle',
#   'actor_2': 'Steven Strait',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0443649'},
#  {'id': '0765429',
#   'mojo_title': 'American Gangster',
#   'domestic_opening_gross': '$43,565,135',
#   'rating': 'R',
#   'foreign_market_count': 68,
#   'genres': 'Biography\n    \n        Crime\n    \n        Drama\n    \n        Thriller',
#   'distributor': 'Universal Pictures',
#   'director': 'Ridley Scott',
#   'actor_1': 'Denzel Washington',
#   'actor_2': 'Russell Crowe',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0765429'},
#  {'id': '0848537',
#   'mojo_title': 'Epic',
#   'domestic_opening_gross': '$33,531,068',
#   'rating': 'PG',
#   'foreign_market_count': 53,
#   'genres': 'Adventure\n    \n        Animation\n    \n        Family\n    \n        Fantasy\n    \n        Mystery\n    \n        Thriller',
#   'distributor': 'Twentieth Century Fox',
#   'director': 'Chris Wedge',
#   'actor_1': 'Amanda Seyfried',
#   'actor_2': 'Josh Hutcherson',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0848537'},
#  {'id': '1528100',
#   'mojo_title': 'Exodus: Gods and Kings',
#   'domestic_opening_gross': '$24,115,934',
#   'rating': 'PG-13',
#   'foreign_market_count': 45,
#   'genres': 'Action\n    \n        Drama\n    \n        Fantasy',
#   'distributor': 'Twentieth Century Fox',
#   'director': 'Ridley Scott',
#   'actor_1': 'Christian Bale',
#   'actor_2': 'Joel Edgerton',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1528100'},
#  {'id': '0034492',
#   'mojo_title': 'Bambi',
#   'domestic_opening_gross': nan,
#   'rating': 'G',
#   'foreign_market_count': 'Do',
#   'genres': 'Animation\n    \n        Drama\n    \n        Family',
#   'distributor': 'RKO Radio Pictures',
#   'director': 'James Algar',
#   'actor_1': 'Hardie Albright',
#   'actor_2': 'Stan Alexander',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0034492'},
#  {'id': '0780521',
#   'mojo_title': 'The Princess and the Frog',
#   'domestic_opening_gross': '$786,190',
#   'rating': nan,
#   'foreign_market_count': 58,
#   'genres': 'Adventure\n    \n        Animation\n    \n        Comedy\n    \n        Family\n    \n        Fantasy\n    \n        Musical\n    \n        Romance',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'director': 'Ron Clements',
#   'actor_1': 'Anika Noni Rose',
#   'actor_2': 'Keith David',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0780521'},
#  {'id': '0103776',
#   'mojo_title': 'Batman Returns',
#   'domestic_opening_gross': '$45,687,711',
#   'rating': 'PG-13',
#   'foreign_market_count': 'EM',
#   'genres': 'Action\n    \n        Crime\n    \n        Fantasy',
#   'distributor': 'Warner Bros.',
#   'director': 'Tim Burton',
#   'actor_1': 'Michael Keaton',
#   'actor_2': 'Danny DeVito',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0103776'},
#  {'id': '0107211',
#   'mojo_title': 'Indecent Proposal',
#   'domestic_opening_gross': '$18,387,632',
#   'rating': 'R',
#   'foreign_market_count': 0,
#   'genres': 'Drama\n    \n        Romance',
#   'distributor': 'Paramount Pictures',
#   'director': 'Adrian Lyne',
#   'actor_1': 'Robert Redford',
#   'actor_2': 'Demi Moore',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0107211'},
#  {'id': '0337741',
#   'mojo_title': "Something's Gotta Give",
#   'domestic_opening_gross': '$16,064,723',
#   'rating': 'PG-13',
#   'foreign_market_count': 28,
#   'genres': 'Comedy\n    \n        Drama\n    \n        Romance',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'director': 'Nancy Meyers',
#   'actor_1': 'Jack Nicholson',
#   'actor_2': 'Diane Keaton',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0337741'},
#  {'id': '0317198',
#   'mojo_title': 'Bridget Jones: The Edge of Reason',
#   'domestic_opening_gross': '$8,684,055',
#   'rating': 'R',
#   'foreign_market_count': 60,
#   'genres': 'Comedy\n    \n        Drama\n    \n        Romance',
#   'distributor': 'Universal Pictures',
#   'director': 'Beeban Kidron',
#   'actor_1': 'Renée Zellweger',
#   'actor_2': 'Colin Firth',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0317198'},
#  {'id': '0800080',
#   'mojo_title': 'The Incredible Hulk',
#   'domestic_opening_gross': '$55,414,050',
#   'rating': 'PG-13',
#   'foreign_market_count': 70,
#   'genres': 'Action\n    \n        Adventure\n    \n        Sci-Fi',
#   'distributor': 'Universal Pictures',
#   'director': 'Louis Leterrier',
#   'actor_1': 'Edward Norton',
#   'actor_2': 'Liv Tyler',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0800080'},
#  {'id': '0114898',
#   'mojo_title': 'Waterworld',
#   'domestic_opening_gross': '$21,171,780',
#   'rating': 'PG-13',
#   'foreign_market_count': 0,
#   'genres': 'Action\n    \n        Adventure\n    \n        Sci-Fi',
#   'distributor': 'Universal Pictures',
#   'director': 'Kevin Reynolds',
#   'actor_1': 'Kevin Costner',
#   'actor_2': 'Jeanne Tripplehorn',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0114898'},
#  {'id': '0120382',
#   'mojo_title': 'The Truman Show',
#   'domestic_opening_gross': '$31,542,121',
#   'rating': 'PG',
#   'foreign_market_count': 5,
#   'genres': 'Comedy\n    \n        Drama\n    \n        Sci-Fi',
#   'distributor': 'Paramount Pictures',
#   'director': 'Peter Weir',
#   'actor_1': 'Jim Carrey',
#   'actor_2': 'Ed Harris',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0120382'},
#  {'id': '0160127',
#   'mojo_title': "Charlie's Angels",
#   'domestic_opening_gross': '$40,128,550',
#   'rating': 'PG-13',
#   'foreign_market_count': 5,
#   'genres': 'Action\n    \n        Adventure\n    \n        Comedy\n    \n        Crime\n    \n        Thriller',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'director': 'McG',
#   'actor_1': 'Cameron Diaz',
#   'actor_2': 'Drew Barrymore',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0160127'},
#  {'id': '0119116',
#   'mojo_title': 'The Fifth Element',
#   'domestic_opening_gross': '$17,031,345',
#   'rating': 'PG-13',
#   'foreign_market_count': 'Do',
#   'genres': 'Action\n    \n        Adventure\n    \n        Sci-Fi',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'director': 'Luc Besson',
#   'actor_1': 'Bruce Willis',
#   'actor_2': 'Milla Jovovich',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0119116'},
#  {'id': '0113497',
#   'mojo_title': 'Jumanji',
#   'domestic_opening_gross': '$11,084,370',
#   'rating': 'PG',
#   'foreign_market_count': 'Do',
#   'genres': 'Adventure\n    \n        Comedy\n    \n        Family\n    \n        Fantasy',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'director': 'Joe Johnston',
#   'actor_1': 'Robin Williams',
#   'actor_2': 'Kirsten Dunst',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0113497'},
#  {'id': '0443453',
#   'mojo_title': 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',
#   'domestic_opening_gross': '$26,455,463',
#   'rating': 'R',
#   'foreign_market_count': 56,
#   'genres': 'Comedy',
#   'distributor': 'Twentieth Century Fox',
#   'director': 'Larry Charles',
#   'actor_1': 'Sacha Baron Cohen',
#   'actor_2': 'Ken Davitian',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0443453'},
#  {'id': '0358082',
#   'mojo_title': 'Robots',
#   'domestic_opening_gross': '$36,045,301',
#   'rating': 'PG',
#   'foreign_market_count': 65,
#   'genres': 'Adventure\n    \n        Animation\n    \n        Comedy\n    \n        Family\n    \n        Sci-Fi',
#   'distributor': 'Twentieth Century Fox',
#   'director': 'Chris Wedge',
#   'actor_1': 'Ewan McGregor',
#   'actor_2': 'Halle Berry',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0358082'},
#  {'id': '1013743',
#   'mojo_title': 'Knight and Day',
#   'domestic_opening_gross': nan,
#   'rating': 'PG-13',
#   'foreign_market_count': 'So',
#   'genres': 'Action\n    \n        Adventure\n    \n        Comedy',
#   'distributor': <span class="money">$117,000,000</span>,
#   'director': 'James Mangold',
#   'actor_1': 'Tom Cruise',
#   'actor_2': 'Cameron Diaz',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1013743'},
#  {'id': '0100802',
#   'mojo_title': 'Total Recall',
#   'domestic_opening_gross': '$25,533,700',
#   'rating': nan,
#   'foreign_market_count': 'Do',
#   'genres': 'Action\n    \n        Sci-Fi\n    \n        Thriller',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'director': 'Paul Verhoeven',
#   'actor_1': 'Arnold Schwarzenegger',
#   'actor_2': 'Sharon Stone',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0100802'},
#  {'id': '1477715',
#   'mojo_title': 'This Is It',
#   'domestic_opening_gross': '$23,234,394',
#   'rating': 'PG',
#   'foreign_market_count': 60,
#   'genres': 'Documentary\n    \n        Drama\n    \n        Music',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'director': 'Kenny Ortega',
#   'actor_1': 'Michael Jackson',
#   'actor_2': 'Alex Al',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1477715'},
#  {'id': '6450804',
#   'mojo_title': 'Terminator: Dark Fate',
#   'domestic_opening_gross': '$29,033,832',
#   'rating': 'R',
#   'foreign_market_count': 49,
#   'genres': 'Action\n    \n        Adventure\n    \n        Sci-Fi',
#   'distributor': 'Paramount Pictures',
#   'director': 'Tim Miller',
#   'actor_1': 'Linda Hamilton',
#   'actor_2': 'Arnold Schwarzenegger',
#   'IMDB_link': 'https://pro.imdb.com/title/tt6450804'},
#  {'id': '1210819',
#   'mojo_title': 'The Lone Ranger',
#   'domestic_opening_gross': '$29,210,849',
#   'rating': 'PG-13',
#   'foreign_market_count': 53,
#   'genres': 'Action\n    \n        Adventure\n    \n        Western',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'director': 'Gore Verbinski',
#   'actor_1': 'Johnny Depp',
#   'actor_2': 'Armie Hammer',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1210819'},
#  {'id': '1650062',
#   'mojo_title': 'Super 8',
#   'domestic_opening_gross': '$35,451,168',
#   'rating': 'PG-13',
#   'foreign_market_count': 65,
#   'genres': 'Action\n    \n        Adventure\n    \n        Sci-Fi\n    \n        Thriller',
#   'distributor': 'Paramount Pictures',
#   'director': 'J.J. Abrams',
#   'actor_1': 'Elle Fanning',
#   'actor_2': 'AJ Michalka',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1650062'},
#  {'id': '1856101',
#   'mojo_title': 'Blade Runner 2049',
#   'domestic_opening_gross': '$32,753,122',
#   'rating': 'R',
#   'foreign_market_count': 75,
#   'genres': 'Action\n    \n        Drama\n    \n        Mystery\n    \n        Sci-Fi\n    \n        Thriller',
#   'distributor': 'Warner Bros.',
#   'director': 'Denis Villeneuve',
#   'actor_1': 'Harrison Ford',
#   'actor_2': 'Ryan Gosling',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1856101'},
#  {'id': '0305357',
#   'mojo_title': "Charlie's Angels: Full Throttle",
#   'domestic_opening_gross': '$37,634,221',
#   'rating': 'PG-13',
#   'foreign_market_count': 27,
#   'genres': 'Action\n    \n        Adventure\n    \n        Comedy\n    \n        Crime',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'director': 'McG',
#   'actor_1': 'Drew Barrymore',
#   'actor_2': 'Lucy Liu',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0305357'},
#  {'id': '0293564',
#   'mojo_title': 'Rush Hour 3',
#   'domestic_opening_gross': '$50,237,000',
#   'rating': 'PG-13',
#   'foreign_market_count': 65,
#   'genres': 'Action\n    \n        Comedy\n    \n        Crime\n    \n        Thriller',
#   'distributor': 'New Line Cinema',
#   'director': 'Brett Ratner',
#   'actor_1': 'Jackie Chan',
#   'actor_2': 'Chris Tucker',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0293564'},
#  {'id': '0119164',
#   'mojo_title': 'The Full Monty',
#   'domestic_opening_gross': '$176,585',
#   'rating': 'R',
#   'foreign_market_count': 59,
#   'genres': 'Comedy\n    \n        Drama',
#   'distributor': 'Fox Searchlight Pictures',
#   'director': 'Peter Cattaneo',
#   'actor_1': 'Robert Carlyle',
#   'actor_2': 'Tom Wilkinson',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0119164'},
#  {'id': '4217392',
#   'mojo_title': 'Kung Fu Yoga',
#   'domestic_opening_gross': '$111,979',
#   'rating': nan,
#   'foreign_market_count': '8 ',
#   'genres': 'Action\n    \n        Adventure\n    \n        Comedy\n    \n        Family\n    \n        Fantasy\n    \n        Mystery',
#   'distributor': 'Well Go USA Entertainment',
#   'director': 'Stanley Tong',
#   'actor_1': 'Jackie Chan',
#   'actor_2': 'Yixing Zhang',
#   'IMDB_link': 'https://pro.imdb.com/title/tt4217392'},
#  {'id': '6751668',
#   'mojo_title': 'Parasite',
#   'domestic_opening_gross': '$393,216',
#   'rating': 'R',
#   'foreign_market_count': '34',
#   'genres': 'Comedy\n    \n        Drama\n    \n        Thriller',
#   'distributor': 'Neon',
#   'director': 'Bong Joon Ho',
#   'actor_1': 'Kang-ho Song',
#   'actor_2': 'Sun-kyun Lee',
#   'IMDB_link': 'https://pro.imdb.com/title/tt6751668'},
#  {'id': '3322940',
#   'mojo_title': 'Annabelle',
#   'domestic_opening_gross': '$37,134,255',
#   'rating': 'R',
#   'foreign_market_count': 53,
#   'genres': 'Horror\n    \n        Mystery\n    \n        Thriller',
#   'distributor': 'Warner Bros.',
#   'director': 'John R. Leonetti',
#   'actor_1': 'Ward Horton',
#   'actor_2': 'Annabelle Wallis',
#   'IMDB_link': 'https://pro.imdb.com/title/tt3322940'},
#  {'id': '0368447',
#   'mojo_title': 'The Village',
#   'domestic_opening_gross': '$50,746,142',
#   'rating': 'PG-13',
#   'foreign_market_count': 37,
#   'genres': 'Drama\n    \n        Mystery\n    \n        Thriller',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'director': 'M. Night Shyamalan',
#   'actor_1': 'Sigourney Weaver',
#   'actor_2': 'William Hurt',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0368447'},
#  {'id': '4242158',
#   'mojo_title': 'Lost in Hong Kong',
#   'domestic_opening_gross': '$537,736',
#   'rating': nan,
#   'foreign_market_count': 8,
#   'genres': 'Action\n    \n        Adventure\n    \n        Comedy\n    \n        Crime\n    \n        Family\n    \n        Romance\n    \n        Thriller',
#   'distributor': 'Well Go USA Entertainment',
#   'director': 'Zheng Xu',
#   'actor_1': 'Zheng Xu',
#   'actor_2': 'Wei Zhao',
#   'IMDB_link': 'https://pro.imdb.com/title/tt4242158'},
#  {'id': '0195685',
#   'mojo_title': 'Erin Brockovich',
#   'domestic_opening_gross': '$28,138,465',
#   'rating': 'R',
#   'foreign_market_count': 1,
#   'genres': 'Biography\n    \n        Drama',
#   'distributor': 'Universal Pictures',
#   'director': 'Steven Soderbergh',
#   'actor_1': 'Julia Roberts',
#   'actor_2': 'Albert Finney',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0195685'},
#  {'id': '0822832',
#   'mojo_title': 'Marley & Me',
#   'domestic_opening_gross': '$36,357,586',
#   'rating': 'PG',
#   'foreign_market_count': 75,
#   'genres': 'Comedy\n    \n        Drama\n    \n        Family',
#   'distributor': 'Twentieth Century Fox',
#   'director': 'David Frankel',
#   'actor_1': 'Owen Wilson',
#   'actor_2': 'Jennifer Aniston',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0822832'},
#  {'id': '1502407',
#   'mojo_title': 'Halloween',
#   'domestic_opening_gross': '$76,221,545',
#   'rating': 'R',
#   'foreign_market_count': 63,
#   'genres': 'Crime\n    \n        Horror\n    \n        Thriller',
#   'distributor': 'Universal Pictures',
#   'director': 'David Gordon Green',
#   'actor_1': 'Jamie Lee Curtis',
#   'actor_2': 'Judy Greer',
#   'IMDB_link': 'https://pro.imdb.com/title/tt1502407'},
#  {'id': '5052448',
#   'mojo_title': 'Get Out',
#   'domestic_opening_gross': nan,
#   'rating': 'R',
#   'foreign_market_count': '3 ',
#   'genres': 'Horror\n    \n        Mystery\n    \n        Thriller',
#   'distributor': <span class="money">$4,500,000</span>,
#   'director': 'Jordan Peele',
#   'actor_1': 'Daniel Kaluuya',
#   'actor_2': 'Allison Williams',
#   'IMDB_link': 'https://pro.imdb.com/title/tt5052448'},
#  {'id': '6857112',
#   'mojo_title': 'Us',
#   'domestic_opening_gross': '$71,117,625',
#   'rating': 'R',
#   'foreign_market_count': 64,
#   'genres': 'Horror\n    \n        Mystery\n    \n        Thriller',
#   'distributor': 'Universal Pictures',
#   'director': 'Jordan Peele',
#   'actor_1': "Lupita Nyong'o",
#   'actor_2': 'Winston Duke',
#   'IMDB_link': 'https://pro.imdb.com/title/tt6857112'},
#  {'id': '0106582',
#   'mojo_title': 'Cliffhanger',
#   'domestic_opening_gross': '$16,176,967',
#   'rating': 'R',
#   'foreign_market_count': 0,
#   'genres': 'Action\n    \n        Adventure\n    \n        Thriller',
#   'distributor': 'TriStar Pictures',
#   'director': 'Renny Harlin',
#   'actor_1': 'Sylvester Stallone',
#   'actor_2': 'John Lithgow',
#   'IMDB_link': 'https://pro.imdb.com/title/tt0106582'}]

# %%
#turn list of dictionaries into dataframe. 
mojo_df = pd.DataFrame(mojo_dict_list)  #convert list of dict to df
mojo_df.set_index('id', inplace=True)

mojo_df.shape
# Out:
# (99, 10)

# %%
#increase recursion limit
import sys
sys.setrecursionlimit(10000)

# %%
#pickle dataframe of each partial url batch. 
#unable to pickle and open pickled dictionaries currently due to UTF 800 error, so df it is.
mojo_df.to_pickle('mojo_df_600.pickle')
