# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
def Get_Top_List(url):
    """
    Converts IMDB table into pandas dataframe.
    Input: url link from IMDB table page for "Top Lifetime Grosses"
    Output: formatted dataframe of table
    """
    
    response = requests.get(url)

    page = response.text

    soup = BeautifulSoup(page)

    table = soup.find(id='table')
    
    rows = [row for row in table.find_all('tr')]

    movies = {} #can also make this a global variable outside of the for loop
    #then pass all the URLS--take URL function and pass it through this function
    #append everything to the movies dictionary and 

    for row in rows[1:]:
        items = row.find_all('td')
        link = items[1].find('a')
        title, url = link.text, link['href']
        movies[title] = [url] + [i.text for i in items]
     
    movie_page = pd.DataFrame(movies).T  #transpose
    movie_page.columns = ['Link', 'Rank', 'Title', 'World_Gross', 
                    'Domestic_Gross', 'Domestic_Percentage', 'Foreign_Gross', 'Foreign_Percentage','Year']

    return movie_page

# %%
Get_Top_List('https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/')
# Out:
#                                                                                Link  \
# Avengers: Endgame                             /title/tt4154796/?ref_=bo_cso_table_1
# Avatar                                        /title/tt0499549/?ref_=bo_cso_table_2
# Titanic                                       /title/tt0120338/?ref_=bo_cso_table_3
# Star Wars: Episode VII - The Force Awakens    /title/tt2488496/?ref_=bo_cso_table_4
# Avengers: Infinity War                        /title/tt4154756/?ref_=bo_cso_table_5
# ...                                                                             ...
# The Revenant                                /title/tt1663202/?ref_=bo_cso_table_196
# The Meg                                     /title/tt4779682/?ref_=bo_cso_table_197
# Ralph Breaks the Internet                   /title/tt5848272/?ref_=bo_cso_table_198
# Hotel Transylvania 3: Summer Vacation       /title/tt5220122/?ref_=bo_cso_table_199
# The Boss Baby                               /title/tt3874544/?ref_=bo_cso_table_200
#
#                                            Rank  \
# Avengers: Endgame                             1
# Avatar                                        2
# Titanic                                       3
# Star Wars: Episode VII - The Force Awakens    4
# Avengers: Infinity War                        5
# ...                                         ...
# The Revenant                                196
# The Meg                                     197
# Ralph Breaks the Internet                   198
# Hotel Transylvania 3: Summer Vacation       199
# The Boss Baby                               200
#
#                                                                                  Title  \
# Avengers: Endgame                                                    Avengers: Endgame
# Avatar                                                                          Avatar
# Titanic                                                                        Titanic
# Star Wars: Episode VII - The Force Awakens  Star Wars: Episode VII - The Force Awakens
# Avengers: Infinity War                                          Avengers: Infinity War
# ...                                                                                ...
# The Revenant                                                              The Revenant
# The Meg                                                                        The Meg
# Ralph Breaks the Internet                                    Ralph Breaks the Internet
# Hotel Transylvania 3: Summer Vacation            Hotel Transylvania 3: Summer Vacation
# The Boss Baby                                                            The Boss Baby
#
#                                                World_Gross Domestic_Gross  \
# Avengers: Endgame                           $2,797,800,564   $858,373,000
# Avatar                                      $2,790,439,092   $760,507,625
# Titanic                                     $2,195,169,869   $659,363,944
# Star Wars: Episode VII - The Force Awakens  $2,068,224,036   $936,662,225
# Avengers: Infinity War                      $2,048,359,754   $678,815,482
# ...                                                    ...            ...
# The Revenant                                  $532,950,503   $183,637,894
# The Meg                                       $530,259,473   $145,443,742
# Ralph Breaks the Internet                     $529,323,962   $201,091,711
# Hotel Transylvania 3: Summer Vacation         $528,583,774   $167,510,016
# The Boss Baby                                 $527,965,936   $175,003,033
#
#                                            Domestic_Percentage  \
# Avengers: Endgame                                        30.7%
# Avatar                                                   27.2%
# Titanic                                                    30%
# Star Wars: Episode VII - The Force Awakens               45.3%
# Avengers: Infinity War                                   33.1%
# ...                                                        ...
# The Revenant                                             34.5%
# The Meg                                                  27.4%
# Ralph Breaks the Internet                                  38%
# Hotel Transylvania 3: Summer Vacation                    31.7%
# The Boss Baby                                            33.2%
#
#                                              Foreign_Gross Foreign_Percentage  \
# Avengers: Endgame                           $1,939,427,564              69.3%
# Avatar                                      $2,029,931,467              72.8%
# Titanic                                     $1,535,805,925                70%
# Star Wars: Episode VII - The Force Awakens  $1,131,561,811              54.7%
# Avengers: Infinity War                      $1,369,544,272              66.9%
# ...                                                    ...                ...
# The Revenant                                  $349,312,609              65.5%
# The Meg                                       $384,815,731              72.6%
# Ralph Breaks the Internet                     $328,232,251                62%
# Hotel Transylvania 3: Summer Vacation         $361,073,758              68.3%
# The Boss Baby                                 $352,962,903              66.8%
#
#                                             Year
# Avengers: Endgame                           2019
# Avatar                                      2009
# Titanic                                     1997
# Star Wars: Episode VII - The Force Awakens  2015
# Avengers: Infinity War                      2018
# ...                                          ...
# The Revenant                                2015
# The Meg                                     2016
# Ralph Breaks the Internet                   2018
# Hotel Transylvania 3: Summer Vacation       2018
# The Boss Baby                               2017
#
# [199 rows x 9 columns]

# %%
def Compile_List(pages):
    """
    Concatenates all the scraped pages of IMDB's "Top Lifetime Grosses" table.
    Input: list of partial URLs referring to pages of IMDB's "Top Lifetime Grosses" table.
    Output: concatenated df of entire table across all pages 
    """
    url = "https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?offset={}"
    dfs = []
    for counter, page in enumerate (pages):
        page_url = url.format(page)
        counter = Get_Top_List(page_url) #should be a list of the dataframes
        dfs.append(counter) 
    return pd.concat(dfs)

# %%
pages = [0, 200, 400, 600, 800, 1000]

top_movies_df = Compile_List(pages)

# %%
top_movies_df.tail()
# Out:
#                                                    Link   Rank  \
# The Wolfman     /title/tt0780653/?ref_=bo_cso_table_196  1,215
# Saw IV          /title/tt0890870/?ref_=bo_cso_table_197  1,216
# Mr. Six         /title/tt4701702/?ref_=bo_cso_table_198  1,217
# Brüno           /title/tt0889583/?ref_=bo_cso_table_199  1,218
# Bird on a Wire  /title/tt0099141/?ref_=bo_cso_table_200  1,219
#
#                          Title   World_Gross Domestic_Gross  \
# The Wolfman        The Wolfman  $139,789,765    $61,979,680
# Saw IV                  Saw IV  $139,352,633    $63,300,095
# Mr. Six                Mr. Six  $139,191,345     $1,415,450
# Brüno                    Brüno  $138,805,831    $60,054,530
# Bird on a Wire  Bird on a Wire  $138,697,012    $70,978,012
#
#                Domestic_Percentage Foreign_Gross Foreign_Percentage  Year
# The Wolfman                  44.3%   $77,810,085              55.7%  2010
# Saw IV                       45.4%   $76,052,538              54.6%  2007
# Mr. Six                         1%  $137,775,895                99%  2015
# Brüno                        43.3%   $78,751,301              56.7%  2009
# Bird on a Wire               51.2%   $67,719,000              48.8%  1990

# %%
top_movies_df.duplicated()
# Out:
# Avengers: Endgame                             False
# Avatar                                        False
# Titanic                                       False
# Star Wars: Episode VII - The Force Awakens    False
# Avengers: Infinity War                        False
#                                               ...
# The Wolfman                                   False
# Saw IV                                        False
# Mr. Six                                       False
# Brüno                                         False
# Bird on a Wire                                False
# Length: 1195, dtype: bool

# %%
top_movies_df.info
# Out:
# <bound method DataFrame.info of                                                                                Link  \
# Avengers: Endgame                             /title/tt4154796/?ref_=bo_cso_table_1
# Avatar                                        /title/tt0499549/?ref_=bo_cso_table_2
# Titanic                                       /title/tt0120338/?ref_=bo_cso_table_3
# Star Wars: Episode VII - The Force Awakens    /title/tt2488496/?ref_=bo_cso_table_4
# Avengers: Infinity War                        /title/tt4154756/?ref_=bo_cso_table_5
# ...                                                                             ...
# The Wolfman                                 /title/tt0780653/?ref_=bo_cso_table_196
# Saw IV                                      /title/tt0890870/?ref_=bo_cso_table_197
# Mr. Six                                     /title/tt4701702/?ref_=bo_cso_table_198
# Brüno                                       /title/tt0889583/?ref_=bo_cso_table_199
# Bird on a Wire                              /title/tt0099141/?ref_=bo_cso_table_200
#
#                                              Rank  \
# Avengers: Endgame                               1
# Avatar                                          2
# Titanic                                         3
# Star Wars: Episode VII - The Force Awakens      4
# Avengers: Infinity War                          5
# ...                                           ...
# The Wolfman                                 1,215
# Saw IV                                      1,216
# Mr. Six                                     1,217
# Brüno                                       1,218
# Bird on a Wire                              1,219
#
#                                                                                  Title  \
# Avengers: Endgame                                                    Avengers: Endgame
# Avatar                                                                          Avatar
# Titanic                                                                        Titanic
# Star Wars: Episode VII - The Force Awakens  Star Wars: Episode VII - The Force Awakens
# Avengers: Infinity War                                          Avengers: Infinity War
# ...                                                                                ...
# The Wolfman                                                                The Wolfman
# Saw IV                                                                          Saw IV
# Mr. Six                                                                        Mr. Six
# Brüno                                                                            Brüno
# Bird on a Wire                                                          Bird on a Wire
#
#                                                World_Gross Domestic_Gross  \
# Avengers: Endgame                           $2,797,800,564   $858,373,000
# Avatar                                      $2,790,439,092   $760,507,625
# Titanic                                     $2,195,169,869   $659,363,944
# Star Wars: Episode VII - The Force Awakens  $2,068,224,036   $936,662,225
# Avengers: Infinity War                      $2,048,359,754   $678,815,482
# ...                                                    ...            ...
# The Wolfman                                   $139,789,765    $61,979,680
# Saw IV                                        $139,352,633    $63,300,095
# Mr. Six                                       $139,191,345     $1,415,450
# Brüno                                         $138,805,831    $60,054,530
# Bird on a Wire                                $138,697,012    $70,978,012
#
#                                            Domestic_Percentage  \
# Avengers: Endgame                                        30.7%
# Avatar                                                   27.2%
# Titanic                                                    30%
# Star Wars: Episode VII - The Force Awakens               45.3%
# Avengers: Infinity War                                   33.1%
# ...                                                        ...
# The Wolfman                                              44.3%
# Saw IV                                                   45.4%
# Mr. Six                                                     1%
# Brüno                                                    43.3%
# Bird on a Wire                                           51.2%
#
#                                              Foreign_Gross Foreign_Percentage  \
# Avengers: Endgame                           $1,939,427,564              69.3%
# Avatar                                      $2,029,931,467              72.8%
# Titanic                                     $1,535,805,925                70%
# Star Wars: Episode VII - The Force Awakens  $1,131,561,811              54.7%
# Avengers: Infinity War                      $1,369,544,272              66.9%
# ...                                                    ...                ...
# The Wolfman                                    $77,810,085              55.7%
# Saw IV                                         $76,052,538              54.6%
# Mr. Six                                       $137,775,895                99%
# Brüno                                          $78,751,301              56.7%
# Bird on a Wire                                 $67,719,000              48.8%
#
#                                             Year
# Avengers: Endgame                           2019
# Avatar                                      2009
# Titanic                                     1997
# Star Wars: Episode VII - The Force Awakens  2015
# Avengers: Infinity War                      2018
# ...                                          ...
# The Wolfman                                 2010
# Saw IV                                      2007
# Mr. Six                                     2015
# Brüno                                       2009
# Bird on a Wire                              1990
#
# [1195 rows x 9 columns]>

# %%
top_movies_df.tail()
# Out:
#                                                    Link   Rank  \
# The Wolfman     /title/tt0780653/?ref_=bo_cso_table_196  1,215
# Saw IV          /title/tt0890870/?ref_=bo_cso_table_197  1,216
# Mr. Six         /title/tt4701702/?ref_=bo_cso_table_198  1,217
# Brüno           /title/tt0889583/?ref_=bo_cso_table_199  1,218
# Bird on a Wire  /title/tt0099141/?ref_=bo_cso_table_200  1,219
#
#                          Title   World_Gross Domestic_Gross  \
# The Wolfman        The Wolfman  $139,789,765    $61,979,680
# Saw IV                  Saw IV  $139,352,633    $63,300,095
# Mr. Six                Mr. Six  $139,191,345     $1,415,450
# Brüno                    Brüno  $138,805,831    $60,054,530
# Bird on a Wire  Bird on a Wire  $138,697,012    $70,978,012
#
#                Domestic_Percentage Foreign_Gross Foreign_Percentage  Year
# The Wolfman                  44.3%   $77,810,085              55.7%  2010
# Saw IV                       45.4%   $76,052,538              54.6%  2007
# Mr. Six                         1%  $137,775,895                99%  2015
# Brüno                        43.3%   $78,751,301              56.7%  2009
# Bird on a Wire               51.2%   $67,719,000              48.8%  1990

# %%
import pickle

# %%
top_movies_df.to_pickle('top_movies_df.pickle')
